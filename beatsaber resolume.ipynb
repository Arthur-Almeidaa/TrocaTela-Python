# %%
import os
import cv2
import numpy as np
from PIL import Image
from time import sleep
import pyautogui
import requests
from keras.models import load_model

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
SIZE = 150

print('Iniciando o modelo...')

model = load_model('keras_model.h5')

model.compile(loss='binary_crossentropy',
             optimizer='Adam',
             metrics=['accuracy'])

status = []

def screenshot():
    # processamento de imagens
    
    pyautogui.screenshot('screenshot.png')     
    image = cv2.imread('screenshot.png')
    image = Image.fromarray(image, 'RGB')
    image = image.resize((SIZE, SIZE))
    input_image = np.expand_dims(image, axis=0)
    
    # predict
    sleep(1)
    predict = model.predict(input_image) 
    
    # envio de informações
    if predict >= 0.5:
        print('Jogando')
        status.append(1)
    else:
        print('Parado')
        status.append(0)
    
    if len(status) >= 3:
        
        # trocar a tela
        if status[0] == 0 and status[1] == 0:
            layer_index = 2
            clip_index = 1 
            
            base_url = f'http://{ip_resolume}/api/v1/composition/layers/{layer_index}/clips/{clip_index}/connect'
            
            response = requests.post(base_url)

        elif status[1] == 0 and status[2] == 0:
            layer_index = 2
            clip_index = 1 
            
            base_url = f'http://{ip_resolume}/api/v1/composition/layers/{layer_index}/clips/{clip_index}/connect'
            response = requests.post(base_url)     
            
        # manter a tela
        elif status[0] == 1 and status[1] == 1:
            layer_index = 2
            clip_index = 2 
            
            base_url = f'http://{ip_resolume}/api/v1/composition/layers/{layer_index}/clips/{clip_index}/connect'
            response = requests.post(base_url)
            
        elif status[1] == 1 and status[2] == 1:
            layer_index = 2
            clip_index = 2 
            
            base_url = f'http://{ip_resolume}/api/v1/composition/layers/{layer_index}/clips/{clip_index}/connect'
            response = requests.post(base_url)
        
        status.pop(0)

while True:
    print('Função chamada')
    screenshot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13024\3158713542.py in <module>
#       7 import pyautogui
#       8 import requests
# ----> 9 from keras.models import load_model
#      10 import schedule
#      11
#
# D:\Anaconda\envs\ProgramaBeat\lib\site-packages\keras\__init__.py in <module>
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# D:\Anaconda\envs\ProgramaBeat\lib\site-packages\keras\models\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# D:\Anaconda\envs\ProgramaBeat\lib\site-packages\keras\engine\functional.py in <module>
# ...
